# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()

# %%
df.sort_values("math score", ascending=False).head(10)
# sort_values() — sorts a DataFrame by one or more columns
# syntax: df.sort_values("column", ascending=False)
# ascending=True  → lowest to highest (default)
# ascending=False → highest to lowest

# %%
df.sort_values("writing score").head(5)

# %%
df.sort_values(["gender", "math score"], ascending=[True, False])
# Multiple columns: df.sort_values(["col1", "col2"], ascending=[True, False])

# %%
df["race/ethnicity"].shape[0]
# shape tells you the size of the whole DataFrame — rows and columns

# %%
df["race/ethnicity"].value_counts()
# value_counts() tells you how many times each unique category appears in one specific column

# %%
df["test preparation course"].value_counts()
